# %%
import torch

# %%
# !pip install -q torch_geometric
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.0 MB/s eta 0:00:00

# %%
import torch_geometric

# %% [markdown]
# # Heading 1

# %% [markdown]
# this is the heading 1 section
#
# <hr>
#
# **bold** text
#
# <font color="orange">orange text</font>
#
# bulleted list:
# - item
# - item
# - item
#
# numbered list:
# 1. item
# 2. item
# 3. item

# %%
print("Hello heading 1")
# Out:
# Hello heading 1

# %% [markdown]
# ## Heading 2

# %% [markdown]
# this is the heading 2 section
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Slika zaslona 2026-02-06 u 13.02.26.png](data:image/png;base64,...)

# %%
print("Hello heading 2")
# Out:
# Hello heading 2

# %% [markdown]
# ### Heading 3

# %% [markdown]
# this is the heading 3 section
